# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from src.data_cleaner import DataCleaner

# %%
# Cellule 1: Configurer le chemin
import sys
import os

# Ajouter le chemin racine
project_root = os.path.abspath('..')
if project_root not in sys.path:
    sys.path.insert(0, project_root)
    print(f"✅ Chemin ajouté: {project_root}")

# Cellule 2: Exécuter le pipeline pour CRÉER les fichiers
from src.pipeline import MarketDataPipeline

print("🚀 CRÉATION du pipeline...")
pipeline = MarketDataPipeline('../config.yaml')

print("📥 TÉLÉCHARGEMENT des données...")
results = pipeline.run_pipeline(
    symbols=['AAPL', 'GOOGL', 'MSFT', 'SPY'],
    start_date='2020-01-01',
    end_date='2023-12-31'
)

print("✅ PIPELINE EXÉCUTÉ avec succès!")
print("📁 Les fichiers ont été créés dans data/processed/")

# Cellule 3: MAINTENANT vous pouvez charger les données
import pandas as pd

aapl = pd.read_csv('../data/processed/AAPL_processed.csv', index_col=0, parse_dates=True)
googl = pd.read_csv('../data/processed/GOOGL_processed.csv', index_col=0, parse_dates=True)
msft = pd.read_csv('../data/processed/MSFT_processed.csv', index_col=0, parse_dates=True)
spy = pd.read_csv('../data/processed/SPY_processed.csv', index_col=0, parse_dates=True)

print(f"\n📊 DONNÉES CHARGÉES avec succès!")
print(f"AAPL: {len(aapl)} lignes")
print(f"GOOGL: {len(googl)} lignes")
print(f"MSFT: {len(msft)} lignes")
print(f"SPY: {len(spy)} lignes")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[23], line 12
#       9     print(f"✅ Chemin ajouté: {project_root}")
#      11 # Cellule 2: Exécuter le pipeline pour CRÉER les fichiers
# ---> 12 from src.pipeline import MarketDataPipeline
#      14 print("🚀 CRÉATION du pipeline...")
#      15 pipeline = MarketDataPipeline('../config.yaml')
#
# File ~/Documents/Market_data_handling/src/pipeline.py:3
#       1 # src/pipeline.py
# ----> 3 from data_fetcher import MarketDataFetcher
#       4 from data_cleaner import DataCleaner
#       5 import pandas as pd
#
# ModuleNotFoundError: No module named 'data_fetcher'

# %%
aapl = pd.read_csv('../data/processed/AAPL_processed.csv', index_col=0, parse_dates=True)
googl = pd.read_csv('../data/processed/GOOGL_processed.csv', index_col=0, parse_dates=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 aapl = pd.read_csv('../data/processed/AAPL_processed.csv', index_col=0, parse_dates=True)
#       2 googl = pd.read_csv('../data/processed/GOOGL_processed.csv', index_col=0, parse_dates=True)
#
# ...
